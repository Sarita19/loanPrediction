# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from scipy.stats import boxcox
import seaborn as sns
import os

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Reading the dataset
#
# There are 3 datasets present. They need to be joined by a common attribute.
#
# -	Borrower Information: Information on the clients’ customers
# -	Loan Classification Information: Information on the loan itself
# -	Loan Payment Information: Information on the payments on the loans.
#
# Between Borrower and Loan Datasets, the common attribute is "member_id" whereas between Loan and Payment Datasets, the common attribute is "id"

# %%
##Reading the dataset
df_borrower = pd.read_csv('C:/Users/sarita.machado/OneDrive - Accenture/Sarita_BEL/myLearning/Projects/Assessment Test/OneDrive_2019-07-04/To be communicated to the candidate/Borrower Information.csv')
df_borrower.head(3)
# Out:
#    Unnamed: 0  member_id emp_title emp_length home_ownership zip_code  \
# 0           1    1296599       NaN  10+ years           RENT    860xx
# 1           2    1314167     Ryder   < 1 year           RENT    309xx
# 2           3    1313524       NaN  10+ years           RENT    606xx
#
#   addr_state  annual_inc  annual_inc_joint  open_acc  pub_rec  total_acc  \
# 0         AZ     24000.0               NaN       3.0      0.0        9.0
# 1         GA     30000.0               NaN       3.0      0.0        4.0
# 2         IL     12252.0               NaN       2.0      0.0       10.0
#
#    delinq_2yrs earliest_cr_line
# 0          0.0         Jan-1985
# 1          0.0         Apr-1999
# 2          0.0         Nov-2001

# %%
df_loan = pd.read_csv('C:/Users/sarita.machado/OneDrive - Accenture/Sarita_BEL/myLearning/Projects/Assessment Test/OneDrive_2019-07-04/To be communicated to the candidate/Loan Classification Information.csv')
df_loan.head(3)
# Out:
# C:\Users\sarita.machado\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0       id  member_id        term grade sub_grade  loan_status  \
# 0           1  1077501    1296599   36 months     B        B2   Fully Paid
# 1           2  1077430    1314167   60 months     C        C4  Charged Off
# 2           3  1077175    1313524   36 months     C        C5   Fully Paid
#
#   pymnt_plan         purpose application_type   issue_d  \
# 0          n     credit_card       INDIVIDUAL  Dec-2011
# 1          n             car       INDIVIDUAL  Dec-2011
# 2          n  small_business       INDIVIDUAL  Dec-2011
#
#                                                 desc                 title  \
# 0    Borrower added on 12/22/11 > I need to upgra...              Computer
# 1    Borrower added on 12/22/11 > I plan to use t...                  bike
# 2                                                NaN  real estate business
#
#    loan_amnt  int_rate  funded_amnt  funded_amnt_inv  installment
# 0       5000     10.65         5000           4975.0       162.87
# 1       2500     15.27         2500           2500.0        59.83
# 2       2400     15.96         2400           2400.0        84.33

# %%
df_pay = pd.read_csv('C:/Users/sarita.machado/OneDrive - Accenture/Sarita_BEL/myLearning/Projects/Assessment Test/OneDrive_2019-07-04/To be communicated to the candidate/Loan Payment Information.csv')
df_pay.head(3)
# Out:
#    Unnamed: 0       id    dti  inq_last_6mths  mths_since_last_delinq  \
# 0           1  1077501  27.65             1.0                     NaN
# 1           2  1077430   1.00             5.0                     NaN
# 2           3  1077175   8.72             2.0                     NaN
#
#    mths_since_last_record  revol_bal  revol_util  out_prncp  out_prncp_inv  \
# 0                     NaN    13648.0        83.7        0.0            0.0
# 1                     NaN     1687.0         9.4        0.0            0.0
# 2                     NaN     2956.0        98.5        0.0            0.0
#
#       ...       mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0     ...                      NaN           NaN      NaN          NaN
# 1     ...                      NaN           NaN      NaN          NaN
# 2     ...                      NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util inq_fi  total_cu_tl inq_last_12m
# 0          NaN         NaN       NaN    NaN          NaN          NaN
# 1          NaN         NaN       NaN    NaN          NaN          NaN
# 2          NaN         NaN       NaN    NaN          NaN          NaN
#
# [3 rows x 41 columns]

# %%
# Joining Borrower and Loan Datasets on "member_id"
df_inter=pd.merge(df_loan,df_borrower, on="member_id")

# %%
df_inter.head(3)
# Out:
#    Unnamed: 0_x       id  member_id        term grade sub_grade  loan_status  \
# 0             1  1077501    1296599   36 months     B        B2   Fully Paid
# 1             2  1077430    1314167   60 months     C        C4  Charged Off
# 2             3  1077175    1313524   36 months     C        C5   Fully Paid
#
#   pymnt_plan         purpose application_type       ...        home_ownership  \
# 0          n     credit_card       INDIVIDUAL       ...                  RENT
# 1          n             car       INDIVIDUAL       ...                  RENT
# 2          n  small_business       INDIVIDUAL       ...                  RENT
#
#   zip_code addr_state  annual_inc  annual_inc_joint  open_acc  pub_rec  \
# 0    860xx         AZ     24000.0               NaN       3.0      0.0
# 1    309xx         GA     30000.0               NaN       3.0      0.0
# 2    606xx         IL     12252.0               NaN       2.0      0.0
#
#    total_acc  delinq_2yrs earliest_cr_line
# 0        9.0          0.0         Jan-1985
# 1        4.0          0.0         Apr-1999
# 2       10.0          0.0         Nov-2001
#
# [3 rows x 31 columns]

# %%
# Joining Intermediate DataSet and Payment Datasets on "id"
df=pd.merge(df_inter,df_pay, on="id")

# %%
df_pay.head(3)
# Out:
#    Unnamed: 0       id    dti  inq_last_6mths  mths_since_last_delinq  \
# 0           1  1077501  27.65             1.0                     NaN
# 1           2  1077430   1.00             5.0                     NaN
# 2           3  1077175   8.72             2.0                     NaN
#
#    mths_since_last_record  revol_bal  revol_util  out_prncp  out_prncp_inv  \
# 0                     NaN    13648.0        83.7        0.0            0.0
# 1                     NaN     1687.0         9.4        0.0            0.0
# 2                     NaN     2956.0        98.5        0.0            0.0
#
#       ...       mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0     ...                      NaN           NaN      NaN          NaN
# 1     ...                      NaN           NaN      NaN          NaN
# 2     ...                      NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util inq_fi  total_cu_tl inq_last_12m
# 0          NaN         NaN       NaN    NaN          NaN          NaN
# 1          NaN         NaN       NaN    NaN          NaN          NaN
# 2          NaN         NaN       NaN    NaN          NaN          NaN
#
# [3 rows x 41 columns]

# %%
df.head(3)
# Out:
#    Unnamed: 0_x       id  member_id        term grade sub_grade  loan_status  \
# 0             1  1077501    1296599   36 months     B        B2   Fully Paid
# 1             2  1077430    1314167   60 months     C        C4  Charged Off
# 2             3  1077175    1313524   36 months     C        C5   Fully Paid
#
#   pymnt_plan         purpose application_type     ...      mths_since_rcnt_il  \
# 0          n     credit_card       INDIVIDUAL     ...                     NaN
# 1          n             car       INDIVIDUAL     ...                     NaN
# 2          n  small_business       INDIVIDUAL     ...                     NaN
#
#   total_bal_il il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# 0          NaN     NaN          NaN          NaN         NaN       NaN
# 1          NaN     NaN          NaN          NaN         NaN       NaN
# 2          NaN     NaN          NaN          NaN         NaN       NaN
#
#    inq_fi  total_cu_tl inq_last_12m
# 0     NaN          NaN          NaN
# 1     NaN          NaN          NaN
# 2     NaN          NaN          NaN
#
# [3 rows x 71 columns]

# %% [markdown]
# Checking the Size of the Merged Data set

# %%
df.shape
# Out:
# (887379, 71)

# %% [markdown]
# ####  Looking for Columns and their % of null data

# %%
df.iloc[df.isnull().sum(1).sort_values(ascending=False).index]
# Out:
#         Unnamed: 0_x        id  member_id        term grade sub_grade  \
# 42450          42451     79924      79906   36 months     A        A3
# 42480          42481     79893      79878   36 months     A        A3
# 42459          42460     71823      70473   36 months     A        A4
# 42449          42450     79967      79912   36 months     A        A2
# 42533          42534     71623      70735   36 months     A        A5
# 42472          42473     72197      72194   36 months     B        B3
# 42532          42533     72176      70868   36 months     B        B3
# 42523          42524     76629      76623   36 months     D        D3
# 42528          42529     74505      74469   36 months     B        B5
# 42527          42528     77757      70626   36 months     B        B3
# 42483          42484     73003      70651   36 months     B        B5
# 42494          42495     72819      72816   36 months     C        C1
# 42530          42531     73582      73096   36 months     C        C1
# 42519          42520     84098      84091   36 months     A        A2
# 42522          42523     83185      83132   36 months     A        A1
# 42529          42530     74323      74301   36 months     B        B4
# 42526          42527     77792      77764   36 months     B        B2
# 42521          42522     83489      83471   36 months     A        A5
# 42520          42521     83979      83974   36 months     A        A2
# 42516          42517     85781      85727   36 months     C        C3
# 42518          42519     84670      79576   36 months     A        A3
# 42531          42532     72998      72992   36 months     B        B4
# 42517          42518     85675      85667   36 months     E        E3
# 42524          42525     74014      73890   36 months     C        C4
# 42515          42516     85818      85802   36 months     C        C4
# 42514          42515     85961      85923   36 months     B        B2
# 42534          42535     70686      70681   36 months     A        A3
# 42509          42510     91023      70879   36 months     B        B4
# 42525          42526     81085      80973   36 months     C        C4
# 4730            4731    997734    1222858   36 months     C        C2
# ...              ...       ...        ...         ...   ...       ...
# 479716        479717  67605282   72468998   60 months     G        G3
# 484577        484578  66631354   71357109   36 months     D        D3
# 479696        479697  67725187   72579899   36 months     B        B2
# 483996        483997  65656270   70289104   36 months     B        B1
# 485474        485475  67326198   72127941   36 months     B        B3
# 479746        479747  67398914   72210692   36 months     B        B5
# 485407        485408  67346238   72147988   36 months     B        B2
# 484009        484010  67347179   72148947   36 months     C        C1
# 482641        482642  67297574   72099333   60 months     D        D5
# 470226        470227  68374257   73264007   36 months     B        B2
# 488490        488491  67155159   71955871   60 months     D        D1
# 473448        473449  67870000   72728756   36 months     D        D2
# 486702        486703  67075490   71876214   36 months     C        C4
# 470256        470257  68394211   73283977   60 months     E        E5
# 485901        485902  67295955   72097689   60 months     D        D4
# 477031        477032  67908276   72766993   36 months     B        B4
# 483372        483373  67457120   72268883   60 months     C        C5
# 487095        487096  67285348   72087066   60 months     E        E1
# 468766        468767  68435132   73324912   60 months     E        E1
# 480179        480180  67495417   72349135   60 months     E        E1
# 479064        479065  67665470   72519186   36 months     B        B5
# 482510        482511  67368015   72179794   60 months     E        E5
# 469545        469546  67526157   72379890   36 months     B        B5
# 487125        487126  67235307   72037025   36 months     B        B2
# 478174        478175  67635666   72489389   60 months     F        F5
# 486513        486514  67335582   72137309   36 months     C        C4
# 476074        476075  67908454   72767175   36 months     D        D4
# 476392        476393  67978748   72837466   36 months     B        B1
# 486533        486534  67295579   72097301   60 months     D        D5
# 466914        466915  68586213   73476013   36 months     E        E1
#
#                                               loan_status pymnt_plan  \
# 42450   Does not meet the credit policy. Status:Fully ...          n
# 42480   Does not meet the credit policy. Status:Fully ...          n
# 42459   Does not meet the credit policy. Status:Fully ...          n
# 42449   Does not meet the credit policy. Status:Fully ...          n
# 42533   Does not meet the credit policy. Status:Fully ...          n
# 42472   Does not meet the credit policy. Status:Fully ...          n
# 42532   Does not meet the credit policy. Status:Fully ...          n
# 42523   Does not meet the credit policy. Status:Charge...          n
# 42528   Does not meet the credit policy. Status:Fully ...          n
# 42527   Does not meet the credit policy. Status:Fully ...          n
# 42483   Does not meet the credit policy. Status:Fully ...          n
# 42494   Does not meet the credit policy. Status:Fully ...          n
# 42530   Does not meet the credit policy. Status:Fully ...          n
# 42519   Does not meet the credit policy. Status:Fully ...          n
# 42522   Does not meet the credit policy. Status:Fully ...          n
# 42529   Does not meet the credit policy. Status:Charge...          n
# 42526   Does not meet the credit policy. Status:Fully ...          n
# 42521   Does not meet the credit policy. Status:Charge...          n
# 42520   Does not meet the credit policy. Status:Fully ...          n
# 42516   Does not meet the credit policy. Status:Fully ...          n
# 42518   Does not meet the credit policy. Status:Fully ...          n
# 42531   Does not meet the credit policy. Status:Fully ...          n
# 42517   Does not meet the credit policy. Status:Fully ...          n
# 42524   Does not meet the credit policy. Status:Fully ...          n
# 42515   Does not meet the credit policy. Status:Fully ...          n
# 42514   Does not meet the credit policy. Status:Fully ...          n
# 42534   Does not meet the credit policy. Status:Fully ...          n
# 42509   Does not meet the credit policy. Status:Fully ...          n
# 42525   Does not meet the credit policy. Status:Fully ...          n
# 4730                                          Charged Off          n
# ...                                                   ...        ...
# 479716                                            Current          n
# 484577                                            Current          n
# 479696                                            Current          n
# 483996                                            Current          n
# 485474                                            Current          n
# 479746                                            Current          n
# 485407                                            Current          n
# 484009                                            Current          n
# 482641                                            Current          n
# 470226                                             Issued          n
# 488490                                            Current          n
# 473448                                             Issued          n
# 486702                                            Current          n
# 470256                                             Issued          n
# 485901                                            Current          n
# 477031                                            Current          n
# 483372                                            Current          n
# 487095                                            Current          n
# 468766                                             Issued          n
# 480179                                             Issued          n
# 479064                                            Current          n
# 482510                                            Current          n
# 469545                                             Issued          n
# 487125                                            Current          n
# 478174                                            Current          n
# 486513                                            Current          n
# 476074                                             Issued          n
# 476392                                            Current          n
# 486533                                            Current          n
# 466914                                            Current          n
#
#                    purpose application_type     ...      mths_since_rcnt_il  \
# 42450                other       INDIVIDUAL     ...                     NaN
# 42480                other       INDIVIDUAL     ...                     NaN
# 42459                other       INDIVIDUAL     ...                     NaN
# 42449                other       INDIVIDUAL     ...                     NaN
# 42533                other       INDIVIDUAL     ...                     NaN
# 42472                other       INDIVIDUAL     ...                     NaN
# 42532                other       INDIVIDUAL     ...                     NaN
# 42523                other       INDIVIDUAL     ...                     NaN
# 42528                other       INDIVIDUAL     ...                     NaN
# 42527                other       INDIVIDUAL     ...                     NaN
# 42483                other       INDIVIDUAL     ...                     NaN
# 42494                other       INDIVIDUAL     ...                     NaN
# 42530                other       INDIVIDUAL     ...                     NaN
# 42519                other       INDIVIDUAL     ...                     NaN
# 42522                other       INDIVIDUAL     ...                     NaN
# 42529                other       INDIVIDUAL     ...                     NaN
# 42526                other       INDIVIDUAL     ...                     NaN
# 42521                other       INDIVIDUAL     ...                     NaN
# 42520                other       INDIVIDUAL     ...                     NaN
# 42516                other       INDIVIDUAL     ...                     NaN
# 42518                other       INDIVIDUAL     ...                     NaN
# 42531                other       INDIVIDUAL     ...                     NaN
# 42517                other       INDIVIDUAL     ...                     NaN
# 42524                other       INDIVIDUAL     ...                     NaN
# 42515                other       INDIVIDUAL     ...                     NaN
# 42514                other       INDIVIDUAL     ...                     NaN
# 42534                other       INDIVIDUAL     ...                     NaN
# 42509   debt_consolidation       INDIVIDUAL     ...                     NaN
# 42525                other       INDIVIDUAL     ...                     NaN
# 4730      home_improvement       INDIVIDUAL     ...                     NaN
# ...                    ...              ...     ...                     ...
# 479716  debt_consolidation       INDIVIDUAL     ...                     5.0
# 484577  debt_consolidation       INDIVIDUAL     ...                    42.0
# 479696         credit_card       INDIVIDUAL     ...                    75.0
# 483996            vacation       INDIVIDUAL     ...                    14.0
# 485474  debt_consolidation       INDIVIDUAL     ...                    23.0
# 479746    home_improvement       INDIVIDUAL     ...                     4.0
# 485407  debt_consolidation       INDIVIDUAL     ...                    13.0
# 484009             medical       INDIVIDUAL     ...                    10.0
# 482641  debt_consolidation       INDIVIDUAL     ...                     1.0
# 470226  debt_consolidation            JOINT     ...                    27.0
# 488490  debt_consolidation            JOINT     ...                    23.0
# 473448    home_improvement            JOINT     ...                    27.0
# 486702  debt_consolidation            JOINT     ...                    14.0
# 470256               other            JOINT     ...                    12.0
# 485901  debt_consolidation            JOINT     ...                     4.0
# 477031  debt_consolidation            JOINT     ...                     2.0
# 483372  debt_consolidation            JOINT     ...                     4.0
# 487095  debt_consolidation            JOINT     ...                    21.0
# 468766  debt_consolidation            JOINT     ...                    17.0
# 480179  debt_consolidation            JOINT     ...                    14.0
# 479064  debt_consolidation            JOINT     ...                    10.0
# 482510  debt_consolidation            JOINT     ...                    19.0
# 469545  debt_consolidation            JOINT     ...                     5.0
# 487125  debt_consolidation            JOINT     ...                    37.0
# 478174  debt_consolidation            JOINT     ...                    14.0
# 486513  debt_consolidation            JOINT     ...                     5.0
# 476074      small_business            JOINT     ...                     2.0
# 476392         credit_card            JOINT     ...                     5.0
# 486533  debt_consolidation            JOINT     ...                     4.0
# 466914  debt_consolidation            JOINT     ...                     3.0
#
#        total_bal_il il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# 42450           NaN     NaN          NaN          NaN         NaN       NaN
# 42480           NaN     NaN          NaN          NaN         NaN       NaN
# 42459           NaN     NaN          NaN          NaN         NaN       NaN
# 42449           NaN     NaN          NaN          NaN         NaN       NaN
# 42533           NaN     NaN          NaN          NaN         NaN       NaN
# 42472           NaN     NaN          NaN          NaN         NaN       NaN
# 42532           NaN     NaN          NaN          NaN         NaN       NaN
# 42523           NaN     NaN          NaN          NaN         NaN       NaN
# 42528           NaN     NaN          NaN          NaN         NaN       NaN
# 42527           NaN     NaN          NaN          NaN         NaN       NaN
# 42483           NaN     NaN          NaN          NaN         NaN       NaN
# 42494           NaN     NaN          NaN          NaN         NaN       NaN
# 42530           NaN     NaN          NaN          NaN         NaN       NaN
# 42519           NaN     NaN          NaN          NaN         NaN       NaN
# 42522           NaN     NaN          NaN          NaN         NaN       NaN
# 42529           NaN     NaN          NaN          NaN         NaN       NaN
# 42526           NaN     NaN          NaN          NaN         NaN       NaN
# 42521           NaN     NaN          NaN          NaN         NaN       NaN
# 42520           NaN     NaN          NaN          NaN         NaN       NaN
# 42516           NaN     NaN          NaN          NaN         NaN       NaN
# 42518           NaN     NaN          NaN          NaN         NaN       NaN
# 42531           NaN     NaN          NaN          NaN         NaN       NaN
# 42517           NaN     NaN          NaN          NaN         NaN       NaN
# 42524           NaN     NaN          NaN          NaN         NaN       NaN
# 42515           NaN     NaN          NaN          NaN         NaN       NaN
# 42514           NaN     NaN          NaN          NaN         NaN       NaN
# 42534           NaN     NaN          NaN          NaN         NaN       NaN
# 42509           NaN     NaN          NaN          NaN         NaN       NaN
# 42525           NaN     NaN          NaN          NaN         NaN       NaN
# 4730            NaN     NaN          NaN          NaN         NaN       NaN
# ...             ...     ...          ...          ...         ...       ...
# 479716      44409.0    86.5          2.0          5.0      1465.0      63.6
# 484577      31873.0   118.4          2.0          2.0      3960.0      86.2
# 479696          0.0     0.0          1.0          4.0      6109.0      43.0
# 483996       3459.0    69.2          1.0          2.0      1495.0      38.6
# 485474      28937.0    68.4          2.0          3.0      3852.0      59.5
# 479746      12481.0    92.5          2.0          3.0      9044.0      75.0
# 485407      22008.0    76.7          1.0          1.0      6042.0      75.0
# 484009      64199.0    84.6          0.0          0.0      7570.0      79.8
# 482641      61489.0   102.0          5.0         16.0      4861.0      29.0
# 470226      20267.0    45.9          1.0          1.0      4961.0      47.5
# 488490      26062.0    71.4          1.0          2.0      1820.0      72.9
# 473448       1518.0    37.9          3.0          3.0      1957.0      42.4
# 486702      53730.0    80.4          1.0          4.0      6656.0      67.9
# 470256      21245.0    89.7          1.0          6.0      1306.0      64.2
# 485901      74983.0    84.5          1.0          2.0     10453.0      75.0
# 477031      26265.0    80.0          0.0          0.0       714.0      79.5
# 483372      11365.0    99.3          0.0          0.0       112.0      93.6
# 487095       8567.0    54.7          1.0          3.0      3262.0      66.3
# 468766      20709.0    83.0          0.0          0.0      7631.0      84.8
# 480179      92408.0    85.1          1.0          2.0      5249.0      62.8
# 479064      21118.0   104.7          3.0          6.0      1335.0      77.6
# 482510      40678.0    83.7          3.0          6.0      4173.0      80.0
# 469545     118025.0   104.6          2.0          3.0      9577.0     101.4
# 487125      16985.0    46.3          0.0          0.0      5513.0      45.2
# 478174      58039.0    83.8          2.0          3.0      2738.0      67.4
# 486513      24671.0    97.8          1.0          4.0       108.0      74.6
# 476074     102320.0    68.9          4.0          8.0      6381.0      67.6
# 476392      73291.0    96.0          0.0          1.0      3994.0      86.6
# 486533      98920.0    93.5          0.0          5.0      2732.0      87.5
# 466914      92313.0    88.9          0.0          1.0      1458.0      89.3
#
#         inq_fi  total_cu_tl inq_last_12m
# 42450      NaN          NaN          NaN
# 42480      NaN          NaN          NaN
# 42459      NaN          NaN          NaN
# 42449      NaN          NaN          NaN
# 42533      NaN          NaN          NaN
# 42472      NaN          NaN          NaN
# 42532      NaN          NaN          NaN
# 42523      NaN          NaN          NaN
# 42528      NaN          NaN          NaN
# 42527      NaN          NaN          NaN
# 42483      NaN          NaN          NaN
# 42494      NaN          NaN          NaN
# 42530      NaN          NaN          NaN
# 42519      NaN          NaN          NaN
# 42522      NaN          NaN          NaN
# 42529      NaN          NaN          NaN
# 42526      NaN          NaN          NaN
# 42521      NaN          NaN          NaN
# 42520      NaN          NaN          NaN
# 42516      NaN          NaN          NaN
# 42518      NaN          NaN          NaN
# 42531      NaN          NaN          NaN
# 42517      NaN          NaN          NaN
# 42524      NaN          NaN          NaN
# 42515      NaN          NaN          NaN
# 42514      NaN          NaN          NaN
# 42534      NaN          NaN          NaN
# 42509      NaN          NaN          NaN
# 42525      NaN          NaN          NaN
# 4730       NaN          NaN          NaN
# ...        ...          ...          ...
# 479716     0.0          4.0          2.0
# 484577     3.0          0.0          8.0
# 479696     0.0          0.0          2.0
# 483996     0.0          2.0          0.0
# 485474     1.0          0.0          0.0
# 479746     1.0          1.0          2.0
# 485407     0.0          0.0          1.0
# 484009     6.0          0.0         17.0
# 482641     3.0          4.0          5.0
# 470226     0.0          0.0          1.0
# 488490     3.0          0.0          0.0
# 473448     1.0          0.0          4.0
# 486702     2.0          2.0          6.0
# 470256     6.0          0.0         11.0
# 485901     1.0          0.0          3.0
# 477031     6.0          0.0          9.0
# 483372     1.0          0.0          0.0
# 487095     0.0          1.0          2.0
# 468766     1.0          0.0          1.0
# 480179     5.0          0.0          1.0
# 479064     2.0          2.0          5.0
# 482510     1.0          5.0          2.0
# 469545     2.0          0.0          1.0
# 487125     1.0          1.0          2.0
# 478174     2.0          1.0          4.0
# 486513     4.0          2.0         10.0
# 476074     0.0          1.0          5.0
# 476392     0.0          4.0          3.0
# 486533     3.0          0.0          4.0
# 466914     4.0          0.0          8.0
#
# [887379 rows x 71 columns]

# %% [markdown]
# #### Looking for variables which have nul values and sorting it based on the maximum amout of null values present

# %%
df_null=pd.DataFrame({'Count': df.isnull().sum(), 'Percent': 100*df.isnull().sum()/len(df)})
df_null.sort_values(by=['Count','Percent'],ascending=False)
#pd.DataFrame({'Count': df.isnull().sum(), 'Percent': 100*df.isnull().sum()/len(df)})
# Out:
#                               Count    Percent
# dti_joint                    886870  99.942640
# annual_inc_joint             886868  99.942415
# il_util                      868762  97.902024
# mths_since_rcnt_il           866569  97.654892
# open_acc_6m                  866007  97.591559
# open_il_6m                   866007  97.591559
# open_il_12m                  866007  97.591559
# open_il_24m                  866007  97.591559
# total_bal_il                 866007  97.591559
# open_rv_12m                  866007  97.591559
# open_rv_24m                  866007  97.591559
# max_bal_bc                   866007  97.591559
# all_util                     866007  97.591559
# inq_fi                       866007  97.591559
# total_cu_tl                  866007  97.591559
# inq_last_12m                 866007  97.591559
# desc                         761351  85.797726
# mths_since_last_record       750326  84.555303
# mths_since_last_major_derog  665676  75.015974
# mths_since_last_delinq       454312  51.197065
# next_pymnt_d                 252971  28.507661
# tot_coll_amt                  70276   7.919502
# tot_cur_bal                   70276   7.919502
# emp_title                     51462   5.799326
# emp_length                    44825   5.051393
# last_pymnt_d                  17659   1.990018
# revol_util                      502   0.056571
# title                           152   0.017129
# collections_12_mths_ex_med      145   0.016340
# last_credit_pull_d               53   0.005973
# ...                             ...        ...
# term                              0   0.000000
# grade                             0   0.000000
# sub_grade                         0   0.000000
# loan_status                       0   0.000000
# pymnt_plan                        0   0.000000
# purpose                           0   0.000000
# application_type                  0   0.000000
# issue_d                           0   0.000000
# loan_amnt                         0   0.000000
# int_rate                          0   0.000000
# funded_amnt                       0   0.000000
# funded_amnt_inv                   0   0.000000
# installment                       0   0.000000
# Unnamed: 0_y                      0   0.000000
# home_ownership                    0   0.000000
# zip_code                          0   0.000000
# addr_state                        0   0.000000
# Unnamed: 0                        0   0.000000
# dti                               0   0.000000
# revol_bal                         0   0.000000
# out_prncp                         0   0.000000
# out_prncp_inv                     0   0.000000
# total_pymnt                       0   0.000000
# total_pymnt_inv                   0   0.000000
# total_rec_prncp                   0   0.000000
# total_rec_int                     0   0.000000
# total_rec_late_fee                0   0.000000
# recoveries                        0   0.000000
# collection_recovery_fee           0   0.000000
# last_pymnt_amnt                   0   0.000000
#
# [71 rows x 2 columns]

# %% [markdown]
# We have 71 columns in the original combined dataset

# %% [markdown]
# If you take a look, there are atleast 15 columns who have more than 80% of their data as 'NA'. Hence we can drop these rows

# %%
df = df.dropna(axis=1, thresh=int(0.80*len(df)))

# %%
df.shape
# Out:
# (887379, 50)

# %% [markdown]
# 21 columns are dropped owing to the fact that they have more than 80% of their data as null

# %%
df.head(3)
# Out:
#    Unnamed: 0_x       id  member_id        term grade sub_grade  loan_status  \
# 0             1  1077501    1296599   36 months     B        B2   Fully Paid
# 1             2  1077430    1314167   60 months     C        C4  Charged Off
# 2             3  1077175    1313524   36 months     C        C5   Fully Paid
#
#   pymnt_plan         purpose application_type     ...     total_rec_late_fee  \
# 0          n     credit_card       INDIVIDUAL     ...                    0.0
# 1          n             car       INDIVIDUAL     ...                    0.0
# 2          n  small_business       INDIVIDUAL     ...                    0.0
#
#   recoveries  collection_recovery_fee  last_pymnt_d  last_pymnt_amnt  \
# 0       0.00                     0.00      Jan-2015           171.62
# 1     117.08                     1.11      Apr-2013           119.66
# 2       0.00                     0.00      Jun-2014           649.91
#
#    last_credit_pull_d  collections_12_mths_ex_med  acc_now_delinq  \
# 0            Jan-2016                         0.0             0.0
# 1            Sep-2013                         0.0             0.0
# 2            Jan-2016                         0.0             0.0
#
#   tot_coll_amt tot_cur_bal
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
#
# [3 rows x 50 columns]

# %%
df_numerical = df.select_dtypes(include ={'float64','int64'}) 
df_numerical.describe()
# Out:
#         Unnamed: 0_x            id     member_id      loan_amnt  \
# count  887379.000000  8.873790e+05  8.873790e+05  887379.000000
# mean   443690.000000  3.246513e+07  3.500182e+07   14755.264605
# std    256164.396598  2.282734e+07  2.411335e+07    8435.455601
# min         1.000000  5.473400e+04  7.047300e+04     500.000000
# 25%    221845.500000  9.206643e+06  1.087713e+07    8000.000000
# 50%    443690.000000  3.443327e+07  3.709528e+07   13000.000000
# 75%    665534.500000  5.490814e+07  5.847135e+07   20000.000000
# max    887379.000000  6.861706e+07  7.354484e+07   35000.000000
#
#             int_rate    funded_amnt  funded_amnt_inv    installment  \
# count  887379.000000  887379.000000    887379.000000  887379.000000
# mean       13.246740   14741.877625     14702.464383     436.717127
# std         4.381867    8429.897657      8442.106732     244.186593
# min         5.320000     500.000000         0.000000      15.670000
# 25%         9.990000    8000.000000      8000.000000     260.705000
# 50%        12.990000   13000.000000     13000.000000     382.550000
# 75%        16.200000   20000.000000     20000.000000     572.600000
# max        28.990000   35000.000000     35000.000000    1445.460000
#
#         Unnamed: 0_y    annual_inc      ...       total_rec_prncp  \
# count  887379.000000  8.873750e+05      ...         887379.000000
# mean   443690.000000  7.502759e+04      ...           5757.706424
# std    256164.396598  6.469830e+04      ...           6625.441046
# min         1.000000  0.000000e+00      ...              0.000000
# 25%    221845.500000  4.500000e+04      ...           1200.570000
# 50%    443690.000000  6.500000e+04      ...           3215.320000
# 75%    665534.500000  9.000000e+04      ...           8000.000000
# max    887379.000000  9.500000e+06      ...          35000.030000
#
#        total_rec_int  total_rec_late_fee     recoveries  \
# count  887379.000000       887379.000000  887379.000000
# mean     1754.804327            0.396692      45.919243
# std      2095.356099            4.087825     409.693874
# min         0.000000            0.000000       0.000000
# 25%       441.460000            0.000000       0.000000
# 50%      1073.280000            0.000000       0.000000
# 75%      2238.265000            0.000000       0.000000
# max     24205.620000          358.680000   33520.270000
#
#        collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
# count            887379.000000    887379.000000               887234.000000
# mean                  4.880757      2164.145585                    0.014380
# std                  63.125281      4794.783233                    0.134191
# min                   0.000000         0.000000                    0.000000
# 25%                   0.000000       280.170000                    0.000000
# 50%                   0.000000       462.780000                    0.000000
# 75%                   0.000000       831.245000                    0.000000
# max                7002.190000     36475.590000                   20.000000
#
#        acc_now_delinq  tot_coll_amt   tot_cur_bal
# count   887350.000000  8.171030e+05  8.171030e+05
# mean         0.004991  2.257026e+02  1.394582e+05
# std          0.077625  1.031137e+04  1.537500e+05
# min          0.000000  0.000000e+00  0.000000e+00
# 25%          0.000000  0.000000e+00  2.985300e+04
# 50%          0.000000  0.000000e+00  8.055900e+04
# 75%          0.000000  0.000000e+00  2.082050e+05
# max         14.000000  9.152545e+06  8.000078e+06
#
# [8 rows x 33 columns]

# %% [markdown]
# We try to remove features which are highly corelated. Variables which are highly correlated should be removed as they disturb in the process of creating predictive models. Here we remove variables that have correlation of 0.65 and above

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.65)]
df.drop(columns=to_drop, axis=1, inplace=True )
#df.drop(df_numerical[to_drop], axis=1, inplace=True )

# %%
df.shape
# Out:
# (887379, 35)

# %% [markdown]
# We managed to remove 15 more columns since these features were highly correlated(as much as 65% or more) to each other

# %%
df.dtypes
# Out:
# Unnamed: 0_x                    int64
# term                           object
# grade                          object
# sub_grade                      object
# loan_status                    object
# pymnt_plan                     object
# purpose                        object
# application_type               object
# issue_d                        object
# title                          object
# loan_amnt                       int64
# int_rate                      float64
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# zip_code                       object
# addr_state                     object
# annual_inc                    float64
# open_acc                      float64
# pub_rec                       float64
# delinq_2yrs                   float64
# earliest_cr_line               object
# dti                           float64
# inq_last_6mths                float64
# revol_bal                     float64
# revol_util                    float64
# total_pymnt                   float64
# total_rec_late_fee            float64
# recoveries                    float64
# last_pymnt_d                   object
# last_credit_pull_d             object
# collections_12_mths_ex_med    float64
# acc_now_delinq                float64
# tot_coll_amt                  float64
# tot_cur_bal                   float64
# dtype: object

# %% [markdown]
# #### Looking to drop columns which intuitively wont add value to the prediction

# %% [markdown]
# We remove the columns which wont add much information to our predictive modeling

# %%
df.drop(['Unnamed: 0_x','zip_code','emp_title','addr_state','earliest_cr_line','issue_d','purpose','collections_12_mths_ex_med','last_credit_pull_d','last_pymnt_d','earliest_cr_line','sub_grade','title','pymnt_plan','application_type'],axis=1,inplace=True)

# %% [markdown]
# Removing the word "months" from the data

# %%
df['term'] = [x[:2] for x in df['term']]
df['term'] = pd.to_numeric(df['term'],errors='coerce')

# %% [markdown]
# Removing the word "years" from the column data

# %%
df['emp_length'] = df['emp_length'].replace({'10+ years':'10'})
df['emp_length'] = df['emp_length'].replace({'< 1 year':'1'})
df['emp_length'] = df['emp_length'].replace({'2 years':'2'})
df['emp_length'] = df['emp_length'].replace({'3 years':'3'})
df['emp_length'] = df['emp_length'].replace({'4 years':'4'})
df['emp_length'] = df['emp_length'].replace({'5 years':'5'})
df['emp_length'] = df['emp_length'].replace({'6 years':'6'})
df['emp_length'] = df['emp_length'].replace({'7 years':'7'})
df['emp_length'] = df['emp_length'].replace({'8 years':'8'})
df['emp_length'] = df['emp_length'].replace({'9 years':'9'})
#df['emp_length'] = [x[:2] for x in df['emp_length']]
df.emp_length.value_counts()
# Out:
# 10        291569
# 2          78870
# 1          70605
# 3          70026
# 1 year     57095
# 5          55704
# 4          52529
# 7          44594
# 8          43955
# 6          42950
# 9          34657
# Name: emp_length, dtype: int64

# %% [markdown]
# Converting the variable emp_length to an integer and replacing the NA values with 0

# %%
df['emp_length'] = pd.to_numeric(df['emp_length'],errors='coerce')
df.emp_length.value_counts()
# Out:
# 10.0    291569
# 0.0     101920
# 2.0      78870
# 1.0      70605
# 3.0      70026
# 5.0      55704
# 4.0      52529
# 7.0      44594
# 8.0      43955
# 6.0      42950
# 9.0      34657
# Name: emp_length, dtype: int64

# %%
df.emp_length.fillna(0,inplace = True)
df.emp_length=df.emp_length.astype(int)

# %%
plt.figure(figsize = [15, 15])
sns.heatmap(df.corr(), annot = True, fmt = '.3f',cmap = 'vlag_r', center = 0)
plt.show()

# %% [markdown]
# Hence we remove variables that are highly co-related to each other amnf categorical variables

# %% [markdown]
# ## Distribution of Loan Value Status

# %%
plt.figure(figsize=(15,5))
loan_status=df['loan_status'].value_counts()
sns.barplot(loan_status.index,loan_status,palette='Pastel1')
plt.xlabel('Count')
plt.title("Loan Value Status")
plt.xticks(rotation=90)
loan_status

# %% [markdown]
# If you see the diagram, there are lots of loans which have status has "Current".With sizeable loans being "Fully Paid". We can remove the records from "In Grace Period" - "Does not meet the credit policy. Status:Charged Off" since they are not sizeable in number.

# %%
#df['loan_status']=df['loan_status'].value_counts()[:5]

# %%
#df.drop(df[(df['loan_status'] == 'Current') & (df['loan_status'] == 'Does not meet the credit policy. Status:Charged Off')].index,inplace=True)df[(df['loan_status'] == 'Current') & (df['loan_status'] == 'Does not meet the credit policy. Status:Charged Off')].index)

df.drop(df[(df['loan_status'] == 'Late (16-30 days)')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'Late (31-120 days)')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'Issued')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'Does not meet the credit policy. Status:Fully Paid')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'Does not meet the credit policy. Status:Charged Off')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'In Grace Period')].index,inplace = True)
df.drop(df[(df['loan_status'] == 'Current')].index,inplace = True)

# %%
plt.figure(figsize=(15,5))
loan_status=df['loan_status'].value_counts()
sns.barplot(loan_status.index,loan_status,palette='Pastel1')
plt.xlabel('Count')
plt.title("Loan Value Status")
plt.xticks(rotation=90)
loan_status

# %%
df['loan_status'] = df['loan_status'].replace({'Charged Off':'Default'})
df['loan_status'].value_counts()
df.loan_status=df.loan_status.astype('category').cat.codes

# %%
df.shape

# %% [markdown]
# ## dropping the null rows since we have sufficient amount of data and there is no need to fill the null values.

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape

# %%
numerical = df.columns[df.dtypes == {'float64','int64'}]
for i in numerical:
    if df[i].min() > 0:
        transformed, lamb = boxcox(df.loc[df[i].notnull(), i])
        if np.abs(1 - lamb) > 0.02:
            df.loc[df[i].notnull(), i] = transformed

# %% [markdown]
# ## One Hot Encoding

# %%
df_string = df.select_dtypes(include ='object') 
#df.drop(columns=df_string, axis=1, inplace=True )
#df.drop(df_numerical,inplace=true )
df_string.dtypes

# %%
dummy_grade=pd.get_dummies(df["grade"], prefix="grade")
dummy_ownership=pd.get_dummies(df["home_ownership"], prefix="ownership")
df=df.join(dummy_grade.ix[:,:])
df=df.join(dummy_ownership.ix[:,:])
df.drop(columns={'grade','home_ownership'},inplace=True )
#dummy_ownership.value_counts()

# %% [markdown]
# ### Creating Dummy Variables using One Hot Encoding

# %%
X = df.ix[:, df.columns != "loan_status"]
y = df["loan_status"]
print(X.shape, y.shape)
# (2137073, 81) (2137073,)
X = pd.get_dummies(X, drop_first=True)
#print(X.shape)
X_dup = X.copy()

# %% [markdown]
# # Building models using all features

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, precision_recall_curve
from sklearn.preprocessing import RobustScaler
X_dup.columns

# %% [markdown]
# Splitting the data using scikitlearn's train_test_split and using 70% data for training and 30% for testing.

# %%
robust_scaler = RobustScaler()
X = robust_scaler.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.30, random_state=123, stratify=y)

# %% [markdown]
# #####We'll now scale the data so that each column has a mean of zero and unit standard deviation. Xunb (unbalanced set) and yunb are the independent and target variable.

# %%
#sc = StandardScaler()
#numerical = X_train.columns[(X_train.dtypes == 'float64') | (X_train.dtypes == 'int64')].tolist()
#X_train[numerical] = sc.fit_transform(X_train[numerical])

# %%
Y_train.shape
X_test.shape

print("X_train is {} ,X_test is {} ,Y_train is {} ,Y_test is {} ".format(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape))
#print("City {} is in the country {}".format(X_train.shape, X_train.shape))

# %% [markdown]
# Now creating the test set for the analysis and scaling it.

# %%
def CMatrix(cm):
    fig, axes = plt.subplots(figsize=(8,6))
    cm = cm.astype('float')/cm.sum(axis=0)
    ax = sns.heatmap(cm, annot=True, cmap='Blues');
    ax.set_xlabel('True Label')
    ax.set_ylabel('Predicted Label')
    ax.axis('equal')

# %% [markdown]
# ## A. Logistic Regression

# %%
logistic_regression = LogisticRegression(C=1)
logistic_regression.fit(X_train, Y_train)
Y_pred_test = logistic_regression.predict(X_test)
CM = confusion_matrix(y_pred=Y_pred_test, y_true=Y_test)
CMatrix(CM)

# %% [markdown]
# ## B. Classification Trees

# %%
from sklearn.tree import DecisionTreeClassifier
class_tree = DecisionTreeClassifier(min_samples_split=30, min_samples_leaf=10, random_state=10)
class_tree.fit(X_train, Y_train)
Y_pred_test = class_tree.predict(X_test)
CM = confusion_matrix(y_pred=Y_pred_test, y_true=Y_test)
CMatrix(CM)

# %% [markdown]
# ## C. Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
NBC = GaussianNB()
NBC.fit(X_train, Y_train)
Y_pred_test = NBC.predict(X_test)
CM = confusion_matrix(y_pred=Y_pred_test, y_true=Y_test)
CMatrix(CM)

# %% [markdown]
# ## D. RandomForestClassifier

# %%
X_dup.columns

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,Y_train)

RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
#clf.feature_importances_
list(df.columns)
feature_imp = pd.Series(clf.feature_importances_,index=X_dup.columns).sort_values(ascending=False)
feature_imp
CM = confusion_matrix(y_pred=Y_pred_test, y_true=Y_test)
CMatrix(CM)
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred=Y_pred_test))

# %% [markdown]
# Based on the above importance, I can again drop the columns which contribute less than 1 %

# %%
#X.drop(columns={'emp_length','inq_last_6mths','tot_coll_amt','delinq_2yrs','grade_A','grade_B','grade_E','pub_rec','ownership_RENT','ownership_MORTGAGE','grade_F','grade_C','grade_D','ownership_OWN','grade_G','acc_now_delinq','ownership_NONE','ownership_OTHER','ownership_ANY'},inplace = True)

# %%
# prediction on test set
y_pred=clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))

# %% [markdown]
# Computing the ROC curves for the models and finding the true positive and false positive

# %%
models = {'NB': GaussianNB(),
          'DT': DecisionTreeClassifier(min_samples_split=30, min_samples_leaf=10, random_state=10),
          'LR': LogisticRegression(C=1),
        'RF': RandomForestClassifier(n_estimators=100)}
unbalset = {}
for i in models.keys():
    scores = cross_val_score(models[i], X_train - np.min(X_train) + 1,
                                    Y_train, cv=3)
    unbalset[i] = scores
    
print(unbalset)

# %%
tp_unbalset, fp_unbalset = createROC(models, X_train - np.min(X_train) + 1, Y_train, X_test - np.min(X_test) + 1, Y_test)

# %%
def createROC(models, X, y, Xte, yte):
    false_p, true_p = [], [] ##false postives and true positives

    for i in models.keys():  ##dict of models
        models[i].fit(X, y)

        fp, tp, threshold = roc_curve(yte, models[i].predict_proba(Xte)[:,1]) ##roc_curve function

        true_p.append(tp)
        false_p.append(fp)
    return true_p, false_p ##returning the true postive and false positive

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,5))
#predict = model.predict(X_train)
ax = pd.DataFrame(unbalset).boxplot(widths=(0.9,0.9,0.9,0.9), grid=False, vert=False, ax=axes[0])
ax.set_ylabel('Classifier')
ax.set_xlabel('Cross-Validation Score')

for i in range(0, len(tp_unbalset)):
    axes[1].plot(fp_unbalset[i], tp_unbalset[i], lw=1)

axes[1].plot([0, 1], [0, 1], '--k', lw=1)
axes[1].legend(models.keys())
axes[1].set_ylabel('True Positive Rate')
axes[1].set_xlabel('False Positive Rate')
axes[1].set_xlim(0,1)
axes[1].set_ylim(0,1)

cm = confusion_matrix(y_pred=Y_pred_test, y_true=Y_test).T
cm = cm.astype('float')/cm.sum(axis=0)

ax = sns.heatmap(cm, annot=True, cmap='Blues', ax=axes[2]);
ax.set_xlabel('True Value')
ax.set_ylabel('Predicted Value')
ax.axis('equal')
